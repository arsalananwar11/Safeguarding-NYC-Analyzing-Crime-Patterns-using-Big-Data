# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append("..")

# %%
from snowflake.snowpark import Session
from snowflake.snowpark.functions import when, col, count, upper
from datetime import date
from helpers import SnowflakeHelper
import json
import os

# %%
snowflake_helper = SnowflakeHelper()
snowflake_config = './../helpers/snowflake_config.json'
session = snowflake_helper.create_snowpark_session(snowflake_config)
# Out:
# [INFO] No schema passed, using default schema SAFEGUARDING_NYC_SCHEMA_BRONZE for the session
# [SUCCESS] Config file loaded successfully!
# [SUCCESS] Snowspark Session created successfully on schema SAFEGUARDING_NYC_SCHEMA_BRONZE!

# %% [markdown]
# ## Extracting Data

# %%
use_of_force_combined = session.table('SAFEGUARDING_NYC_SCHEMA_GOLD.use_of_force_combined')
sqf = session.table('SAFEGUARDING_NYC_SCHEMA_SILVER.SQF')

# %%
use_of_force_combined.show()
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"FORCETYPE"        |"INCIDENT PCT"  |"TRI INCIDENT NUMBER"  |"PATROL BOROUGH"  |"OCCURRENCE DATE"  |"FORCE AGAINST MOS"  |"AGE"  |"SUBJECT GENDER"  |"SUBJECT RACE"  |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |Physical Force     |1               |2020020962067          |MANHATTAN         |2020-05-06         |Physical Force       |NULL   |MALE              |BLACK           |
# |Physical Force     |1               |2020020962143          |MANHATTAN         |2020-10-11         |Physical Force       |NULL   |MALE              |BLACK           |
# |Physical Force     |5               |2020024962080          |MANHATTAN         |2020-06-30         |Physical Force       |NULL   |MALE              |BLACK           |
# |Electrical Weapon  |6               |2020025962038          |MANHATTAN         |2020-03-02         |Physical Force       |NULL   |MALE              |BLACK           |
# |Physical Force     |6               |2020025962049          |MANHATTAN         |2020-03-25         |Physical Force       |NULL   |MALE              |BLACK           |
# |Physical Force     |6               |2020025962140          |MANHATTAN         |2020-11-02         |Physical Force       |NULL   |MALE              |BLACK           |
# |Physical Force     |7               |2020026962081          |MANHATTAN         |2020-11-27         |Physical Force       |NULL   |MALE              |BLACK           |
# |Electrical Weapon  |13              |2020032962033          |MANHATTAN         |2020-03-06         |Physical Force       |NULL   |MALE              |BLACK           |
# |Electrical Weapon  |13              |2020032962062          |MANHATTAN         |2020-04-26         |Physical Force       |NULL   |MALE              |BLACK           |
# |Physical Force     |13              |2020032962112          |MANHATTAN         |2020-06-25         |Physical Force       |NULL   |MALE              |BLACK           |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sqf.show()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"PHYSICAL_FORCE_OC_SPRAY_USED_FLAG"  |"SEARCH_BASIS_HARD_OBJECT_FLAG"  |"SUSPECT_WEIGHT"  |"STOP_LOCATION_SECTOR_CODE"  |"OTHER_WEAPON_FLAG"  |"PHYSICAL_FORCE_WEAPON_IMPACT_FLAG"  |"STOP_LOCATION_STREET_NAME"  |"STOP_DURATION_MINUTES"  |"PHYSICAL_FORCE_OTHER_FLAG"  |"SUSPECT_SEX"  |"ASK_FOR_CONSENT_FLG"  |"SUMMONS_OFFENSE_DESCRIPTION"  |"STOP_LOCATION_X"  |"SUSPECTS_ACTIONS_CONCEALED_POSSESSION_WEAPON_F...  |"SUSPECTS_ACTIONS_OTHER_FLAG"  |"PHYSICAL_FORCE_CEW_FLAG"  |"STOP_LOCATION_Y"  |"DAY2"     |"FIREARM_FLAG"  |"WEAPON_FOUND_FLAG"  |"MONTH2"  |"SEARCH_BASIS_INCIDENTAL_TO_ARREST_FLAG"  |"SUSPECTS_ACTIONS_DRUG_TRANSACTIONS_FLAG"  |"BACKROUND_CIRCUMSTANCES_VIOLENT_CRIME_FLAG"  |"FRISKED_FLAG"  |"SUSPECT_HAIR_COLOR"  |"SUSPECT_ARREST_OFFENSE"  |"OFFICER_IN_UNIFORM_FLAG"  |"STOP_LOCATION_APARTMENT"  |"JURISDICTION_CODE"  |"SEARCHED_FLAG"  |"SUSPECTED_CRIME_DESCRIPTION"  |"SUSPECT_HEIGHT"  |"SUSPECTS_ACTIONS_DECRIPTION_FLAG"  |"KNIFE_CUTTER_FLAG"  |"SUPERVISING_OFFICER_RANK"  |"STOP_LOCATION_FULL_ADDRESS"    |"OTHER_CONTRABAND_FLAG"  |"SUSPECT_BODY_BUILD_TYPE"  |"PHYSICAL_FORCE_DRAW_POINT_FIREARM_FLAG"  |"DEMEANOR_OF_PERSON_STOPPED"  |"SUSPECT_ARRESTED_FLAG"  |"SUSPECT_RACE_DESCRIPTION"  |"SUSPECT_REPORTED_AGE"  |"SUSPECT_EYE_COLOR"  |"STOP_FRISK_TIME"  |"OBSERVED_DURATION_MINUTES"  |"CONSENT_GIVEN_FLG"  |"STOP_WAS_INITIATED"     |"SEARCH_BASIS_OUTLINE_FLAG"  |"SHIELD_IDENTIFIES_OFFICER_FLAG"  |"ISSUING_OFFICER_RANK"  |"OFFICER_EXPLAINED_STOP_FLAG"  |"STOP_LOCATION_PRECINCT"  |"SUSPECT_OTHER_DESCRIPTION"                         |"SUSPECTS_ACTIONS_IDENTIFY_CRIME_PATTERN_FLAG"  |"SUSPECTS_ACTIONS_LOOKOUT_FLAG"  |"STOP_LOCATION_PATROL_BORO_NAME"  |"STOP_LOCATION_BORO_NAME"  |"YEAR2"  |"STOP_FRISK_DATE"  |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET                |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene    |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                                             |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |NULL                                 |NULL                             |190               |C                            |NULL                 |NULL                                 |WHITE STREET                 |10                       |NULL                         |MALE           |N                      |NULL                           |982650             |NULL                                                |Y                              |NULL                       |201326             |Tuesday    |NULL            |N                    |January   |Y                                         |NULL                                       |NULL                                          |N               |BLK                   |GRAND LARCENY             |N                          |NULL                       |P                    |Y                |GRAND LARCENY                  |5.1               |NULL                                |NULL                 |SGT                         |9 WHITE STREET                  |N                        |MED                        |NULL                                      |NORMAL                        |Y                        |BLACK                       |22                      |BRO                  |2:30:00            |1                            |N                    |Based on Self Initiated  |NULL                         |S                                 |POM                     |Y                              |1                         |NULL                                                |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-08         |
# |NULL                                 |NULL                             |250               |D                            |NULL                 |NULL                                 |SPRING STREET                |4                        |NULL                         |MALE           |N                      |NULL                           |984063             |NULL                                                |NULL                           |NULL                       |203033             |Saturday   |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |N               |BLK                   |PETIT LARCENY             |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.9               |Y                                   |NULL                 |SGT                         |131 SPRING STREET               |N                        |HEA                        |NULL                                      |CALM                          |Y                        |WHITE                       |56                      |BLU                  |16:54:00           |1                            |NULL                 |Based on Radio Run       |NULL                         |NULL                              |POM                     |Y                              |1                         |BLACK LONG COAT, BLACK PANTS, BLACK FEDORA HAT,...  |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-12         |
# |NULL                                 |NULL                             |NULL              |NULL                         |NULL                 |NULL                                 |GRAND STREET                 |5                        |NULL                         |MALE           |N                      |NULL                           |982848             |NULL                                                |NULL                           |NULL                       |202677             |Monday     |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |N               |NULL                  |NULL                      |Y                          |NULL                       |P                    |N                |ROBBERY                        |NULL              |Y                                   |NULL                 |SGT                         |GRAND STREET && 6TH AVE         |N                        |NULL                       |NULL                                      |CONFUSED                      |N                        |BLACK                       |NULL                    |NULL                 |21:21:00           |0                            |N                    |Based on Radio Run       |NULL                         |NULL                              |POM                     |Y                              |1                         |NULL                                                |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-14         |
# |NULL                                 |NULL                             |150               |D                            |NULL                 |NULL                                 |THOMPSON STREET              |5                        |NULL                         |MALE           |N                      |NULL                           |983100             |NULL                                                |NULL                           |NULL                       |202705             |Tuesday    |NULL            |N                    |January   |NULL                                      |NULL                                       |Y                                             |Y               |BLK                   |ASSAULT                   |N                          |NULL                       |P                    |N                |ASSAULT                        |5.9               |Y                                   |NULL                 |SGT                         |32 THOMPSON STREET              |N                        |THN                        |NULL                                      |#N/A                          |Y                        |BLACK                       |21                      |BLK                  |18:50:00           |1                            |N                    |Based on Radio Run       |NULL                         |S                                 |POM                     |Y                              |1                         |NULL                                                |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-15         |
# |NULL                                 |NULL                             |150               |B                            |NULL                 |NULL                                 |STONE STREET                 |5                        |NULL                         |MALE           |N                      |NULL                           |980765             |NULL                                                |Y                              |NULL                       |195773             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |Y                                             |Y               |RED                   |NULL                      |Y                          |NULL                       |P                    |N                |BURGLARY                       |5.9               |NULL                                |NULL                 |SGT                         |8 STONE STREET                  |N                        |MED                        |NULL                                      |COORPERATIVE                  |N                        |BLACK                       |17                      |BLK                  |6:16:00            |1                            |N                    |Based on Radio Run       |NULL                         |NULL                              |POM                     |Y                              |1                         |BLACK WOODED JACKET                                 |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-23         |
# |NULL                                 |NULL                             |220               |B                            |NULL                 |NULL                                 |BROADWAY                     |3                        |NULL                         |MALE           |N                      |NULL                           |980671             |NULL                                                |NULL                           |NULL                       |196590             |Thursday   |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |N               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |ASSAULT                        |6.2               |Y                                   |NULL                 |SGT                         |42 BROADWAY                     |N                        |MED                        |NULL                                      |COOPERATIVE                   |N                        |BLACK                       |21                      |BRO                  |12:16:00           |1                            |N                    |Based on Radio Run       |NULL                         |NULL                              |POM                     |Y                              |1                         |NA                                                  |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-24         |
# |NULL                                 |NULL                             |150               |B                            |NULL                 |NULL                                 |STONE STREET                 |5                        |NULL                         |MALE           |N                      |NULL                           |980765             |NULL                                                |Y                              |NULL                       |195773             |Tuesday    |NULL            |N                    |January   |NULL                                      |NULL                                       |Y                                             |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |BURGLARY                       |5.9               |NULL                                |NULL                 |SGT                         |8 STONE STREET                  |N                        |MED                        |NULL                                      |COOPERATIVE                   |N                        |BLACK HISPANIC              |NULL                    |BRO                  |6:16:00            |1                            |N                    |Based on Radio Run       |NULL                         |NULL                              |POM                     |Y                              |1                         |BLACK SWEATSHIRT DU-RAG                             |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-22         |
# |NULL                                 |NULL                             |140               |A                            |NULL                 |NULL                                 |WALL STREET                  |5                        |NULL                         |MALE           |N                      |NULL                           |981863             |NULL                                                |NULL                           |NULL                       |196460             |Monday     |NULL            |N                    |February  |NULL                                      |NULL                                       |NULL                                          |N               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.7               |Y                                   |NULL                 |SGT                         |60 WALL STREET                  |N                        |THN                        |NULL                                      |CALM                          |N                        |BLACK                       |26                      |BRO                  |14:09:00           |1                            |N                    |Based on Radio Run       |NULL                         |NULL                              |POM                     |Y                              |1                         |N/A                                                 |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-02-04         |
# |NULL                                 |Y                                |125               |A                            |NULL                 |NULL                                 |NASSAU STREET                |10                       |NULL                         |MALE           |Y                      |NULL                           |982103             |Y                                                   |NULL                           |NULL                       |198029             |Monday     |NULL            |Y                    |February  |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |MENACING                  |Y                          |NULL                       |T                    |Y                |MENACING                       |5.5               |Y                                   |Y                    |SGT                         |NASSAU STREET && FULTON STREET  |N                        |THN                        |NULL                                      |NEUTRAL, NON HOSTILE          |Y                        |BLACK                       |17                      |BRO                  |9:05:00            |0                            |Y                    |Based on C/W on Scene    |NULL                         |NULL                              |POM                     |Y                              |1                         |RED BUBBLE JACKET, GRAY SWEATSHIRT, GRAY SWEATS     |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-02-11         |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
use_of_force_combined.count()
# Out:
# 29723

# %%
sqf.count()
# Out:
# 101989

# %%
# Aggregate use_of_force_combined by INCIDENT PCT
agg_use_of_force = use_of_force_combined.groupBy("INCIDENT PCT").agg(count("*").alias("incident_count"))

# Aggregate sqf by STOP_LOCATION_PRECINCT
agg_sqf = sqf.groupBy("STOP_LOCATION_PRECINCT").agg(count("*").alias("stop_count"))

# Join the aggregated results
use_of_force_and_sqf_agg = agg_use_of_force.join(
    agg_sqf, 
    agg_use_of_force["INCIDENT PCT"] == agg_sqf["STOP_LOCATION_PRECINCT"], 
    how="inner"
)

# View the results
use_of_force_and_sqf_agg.show()
# Out:
# -------------------------------------------------------------------------------
# |"INCIDENT PCT"  |"INCIDENT_COUNT"  |"STOP_LOCATION_PRECINCT"  |"STOP_COUNT"  |
# -------------------------------------------------------------------------------
# |5               |320               |5                         |704           |
# |6               |329               |6                         |847           |
# |10              |213               |10                        |656           |
# |14              |877               |14                        |1342          |
# |17              |139               |17                        |363           |
# |18              |384               |18                        |972           |
# |19              |280               |19                        |1544          |
# |33              |327               |33                        |958           |
# |34              |366               |34                        |1394          |
# |41              |354               |41                        |887           |
# -------------------------------------------------------------------------------

# %%
agg_use_of_force.count()
# Out:
# 77

# %% [markdown]
# ## Joining Use Of Forces Tables

# %% [markdown]
# ### On PRECINCT

# %%
use_of_force_and_sqf_on_precinct = use_of_force_combined.join(
    sqf, 
    use_of_force_combined['INCIDENT PCT'] == sqf['STOP_LOCATION_PRECINCT'], 
    how="inner"
)
use_of_force_and_sqf_on_precinct.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"FORCETYPE"        |"INCIDENT PCT"  |"TRI INCIDENT NUMBER"  |"PATROL BOROUGH"  |"OCCURRENCE DATE"  |"FORCE AGAINST MOS"  |"AGE"  |"SUBJECT GENDER"  |"SUBJECT RACE"  |"PHYSICAL_FORCE_OC_SPRAY_USED_FLAG"  |"SEARCH_BASIS_HARD_OBJECT_FLAG"  |"SUSPECT_WEIGHT"  |"STOP_LOCATION_SECTOR_CODE"  |"OTHER_WEAPON_FLAG"  |"PHYSICAL_FORCE_WEAPON_IMPACT_FLAG"  |"STOP_LOCATION_STREET_NAME"  |"STOP_DURATION_MINUTES"  |"PHYSICAL_FORCE_OTHER_FLAG"  |"SUSPECT_SEX"  |"ASK_FOR_CONSENT_FLG"  |"SUMMONS_OFFENSE_DESCRIPTION"  |"STOP_LOCATION_X"  |"SUSPECTS_ACTIONS_CONCEALED_POSSESSION_WEAPON_F...  |"SUSPECTS_ACTIONS_OTHER_FLAG"  |"PHYSICAL_FORCE_CEW_FLAG"  |"STOP_LOCATION_Y"  |"DAY2"     |"FIREARM_FLAG"  |"WEAPON_FOUND_FLAG"  |"MONTH2"  |"SEARCH_BASIS_INCIDENTAL_TO_ARREST_FLAG"  |"SUSPECTS_ACTIONS_DRUG_TRANSACTIONS_FLAG"  |"BACKROUND_CIRCUMSTANCES_VIOLENT_CRIME_FLAG"  |"FRISKED_FLAG"  |"SUSPECT_HAIR_COLOR"  |"SUSPECT_ARREST_OFFENSE"  |"OFFICER_IN_UNIFORM_FLAG"  |"STOP_LOCATION_APARTMENT"  |"JURISDICTION_CODE"  |"SEARCHED_FLAG"  |"SUSPECTED_CRIME_DESCRIPTION"  |"SUSPECT_HEIGHT"  |"SUSPECTS_ACTIONS_DECRIPTION_FLAG"  |"KNIFE_CUTTER_FLAG"  |"SUPERVISING_OFFICER_RANK"  |"STOP_LOCATION_FULL_ADDRESS"  |"OTHER_CONTRABAND_FLAG"  |"SUSPECT_BODY_BUILD_TYPE"  |"PHYSICAL_FORCE_DRAW_POINT_FIREARM_FLAG"  |"DEMEANOR_OF_PERSON_STOPPED"  |"SUSPECT_ARRESTED_FLAG"  |"SUSPECT_RACE_DESCRIPTION"  |"SUSPECT_REPORTED_AGE"  |"SUSPECT_EYE_COLOR"  |"STOP_FRISK_TIME"  |"OBSERVED_DURATION_MINUTES"  |"CONSENT_GIVEN_FLG"  |"STOP_WAS_INITIATED"   |"SEARCH_BASIS_OUTLINE_FLAG"  |"SHIELD_IDENTIFIES_OFFICER_FLAG"  |"ISSUING_OFFICER_RANK"  |"OFFICER_EXPLAINED_STOP_FLAG"  |"STOP_LOCATION_PRECINCT"  |"SUSPECT_OTHER_DESCRIPTION"  |"SUSPECTS_ACTIONS_IDENTIFY_CRIME_PATTERN_FLAG"  |"SUSPECTS_ACTIONS_LOOKOUT_FLAG"  |"STOP_LOCATION_PATROL_BORO_NAME"  |"STOP_LOCATION_BORO_NAME"  |"YEAR2"  |"STOP_FRISK_DATE"  |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |Physical Force     |1               |2020020962067          |MANHATTAN         |2020-05-06         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Physical Force     |1               |2020020962143          |MANHATTAN         |2020-10-11         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Physical Force     |1               |2021020962035          |MANHATTAN         |2021-02-16         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Physical Force     |1               |2021020962049          |MANHATTAN         |2021-04-06         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Physical Force     |1               |2021020962059          |MANHATTAN         |2021-05-24         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Electrical Weapon  |1               |2022020962024          |MANHATTAN         |2022-01-24         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Physical Force     |1               |2022020962042          |MANHATTAN         |2022-03-17         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |OC Spray           |1               |2022020962058          |MANHATTAN         |2022-04-11         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Physical Force     |1               |2022020962065          |MANHATTAN         |2022-04-28         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# |Physical Force     |1               |2022020962072          |MANHATTAN         |2022-05-09         |Physical Force       |NULL   |MALE              |BLACK           |NULL                                 |NULL                             |230               |C                            |NULL                 |NULL                                 |VESEY STREET                 |10                       |NULL                         |MALE           |Y                      |NULL                           |979667             |NULL                                                |Y                              |NULL                       |199737             |Wednesday  |NULL            |N                    |January   |NULL                                      |NULL                                       |NULL                                          |Y               |BLK                   |NULL                      |Y                          |NULL                       |P                    |N                |PETIT LARCENY                  |5.11              |NULL                                |NULL                 |SGT                         |230 VESEY STREET              |N                        |HEA                        |NULL                                      |UNDERSTANDING                 |N                        |BLACK                       |30                      |BRO                  |14:30:00           |1                            |Y                    |Based on C/W on Scene  |NULL                         |NULL                              |POM                     |Y                              |1                         |UNKNOWN                      |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2019     |2019-01-02         |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
use_of_force_and_sqf_on_precinct.count()
# Out:
# 45736869

# %% [markdown]
# ### On Borough

# %%
use_of_force_and_sqf_on_borough = use_of_force_combined.join(
    sqf, 
    use_of_force_combined['PATROL BOROUGH'] == sqf['STOP_LOCATION_PATROL_BORO_NAME'], 
    how="inner"
)
use_of_force_and_sqf_on_borough.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"FORCETYPE"        |"INCIDENT PCT"  |"TRI INCIDENT NUMBER"  |"PATROL BOROUGH"  |"OCCURRENCE DATE"  |"FORCE AGAINST MOS"  |"AGE"  |"SUBJECT GENDER"  |"SUBJECT RACE"  |"PHYSICAL_FORCE_OC_SPRAY_USED_FLAG"  |"SEARCH_BASIS_HARD_OBJECT_FLAG"  |"SUSPECT_WEIGHT"  |"STOP_LOCATION_SECTOR_CODE"  |"OTHER_WEAPON_FLAG"  |"PHYSICAL_FORCE_WEAPON_IMPACT_FLAG"  |"STOP_LOCATION_STREET_NAME"  |"STOP_DURATION_MINUTES"  |"PHYSICAL_FORCE_OTHER_FLAG"  |"SUSPECT_SEX"  |"ASK_FOR_CONSENT_FLG"  |"SUMMONS_OFFENSE_DESCRIPTION"  |"STOP_LOCATION_X"  |"SUSPECTS_ACTIONS_CONCEALED_POSSESSION_WEAPON_F...  |"SUSPECTS_ACTIONS_OTHER_FLAG"  |"PHYSICAL_FORCE_CEW_FLAG"  |"STOP_LOCATION_Y"  |"DAY2"  |"FIREARM_FLAG"  |"WEAPON_FOUND_FLAG"  |"MONTH2"  |"SEARCH_BASIS_INCIDENTAL_TO_ARREST_FLAG"  |"SUSPECTS_ACTIONS_DRUG_TRANSACTIONS_FLAG"  |"BACKROUND_CIRCUMSTANCES_VIOLENT_CRIME_FLAG"  |"FRISKED_FLAG"  |"SUSPECT_HAIR_COLOR"  |"SUSPECT_ARREST_OFFENSE"  |"OFFICER_IN_UNIFORM_FLAG"  |"STOP_LOCATION_APARTMENT"  |"JURISDICTION_CODE"  |"SEARCHED_FLAG"  |"SUSPECTED_CRIME_DESCRIPTION"  |"SUSPECT_HEIGHT"  |"SUSPECTS_ACTIONS_DECRIPTION_FLAG"  |"KNIFE_CUTTER_FLAG"  |"SUPERVISING_OFFICER_RANK"  |"STOP_LOCATION_FULL_ADDRESS"  |"OTHER_CONTRABAND_FLAG"  |"SUSPECT_BODY_BUILD_TYPE"  |"PHYSICAL_FORCE_DRAW_POINT_FIREARM_FLAG"  |"DEMEANOR_OF_PERSON_STOPPED"  |"SUSPECT_ARRESTED_FLAG"  |"SUSPECT_RACE_DESCRIPTION"  |"SUSPECT_REPORTED_AGE"  |"SUSPECT_EYE_COLOR"  |"STOP_FRISK_TIME"  |"OBSERVED_DURATION_MINUTES"  |"CONSENT_GIVEN_FLG"  |"STOP_WAS_INITIATED"  |"SEARCH_BASIS_OUTLINE_FLAG"  |"SHIELD_IDENTIFIES_OFFICER_FLAG"  |"ISSUING_OFFICER_RANK"  |"OFFICER_EXPLAINED_STOP_FLAG"  |"STOP_LOCATION_PRECINCT"  |"SUSPECT_OTHER_DESCRIPTION"    |"SUSPECTS_ACTIONS_IDENTIFY_CRIME_PATTERN_FLAG"  |"SUSPECTS_ACTIONS_LOOKOUT_FLAG"  |"STOP_LOCATION_PATROL_BORO_NAME"  |"STOP_LOCATION_BORO_NAME"  |"YEAR2"  |"STOP_FRISK_DATE"  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |Physical Force     |115             |2023134962090          |QUEENS            |2023-07-01         |No Force             |17     |MALE              |HISPANIC        |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |115             |2023134962097          |QUEENS            |2023-07-14         |No Force             |32     |MALE              |HISPANIC        |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |100             |2020119962015          |QUEENS            |2020-01-08         |No Force             |14     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Electrical Weapon  |100             |2020119962035          |QUEENS            |2020-05-18         |No Force             |15     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |100             |2020119962038          |QUEENS            |2020-06-03         |No Force             |31     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |100             |2020119962041          |QUEENS            |2020-06-12         |No Force             |32     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |100             |2020119962067          |QUEENS            |2020-11-27         |No Force             |35     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |101             |2020120962047          |QUEENS            |2020-03-11         |No Force             |55     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |101             |2020120962066          |QUEENS            |2020-05-11         |No Force             |16     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |101             |2020120962076          |QUEENS            |2020-05-21         |No Force             |39     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
use_of_force_and_sqf_on_borough.count()
# Out:
# 725171410

# %% [markdown]
# #### On Date

# %%
use_of_force_and_sqf_on_date = use_of_force_combined.join(
    sqf, 
    use_of_force_combined['OCCURRENCE DATE'] == sqf['STOP_FRISK_DATE'], 
    how="inner"
)
use_of_force_and_sqf_on_date.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"FORCETYPE"        |"INCIDENT PCT"  |"TRI INCIDENT NUMBER"  |"PATROL BOROUGH"  |"OCCURRENCE DATE"  |"FORCE AGAINST MOS"  |"AGE"  |"SUBJECT GENDER"  |"SUBJECT RACE"  |"PHYSICAL_FORCE_OC_SPRAY_USED_FLAG"  |"SEARCH_BASIS_HARD_OBJECT_FLAG"  |"SUSPECT_WEIGHT"  |"STOP_LOCATION_SECTOR_CODE"  |"OTHER_WEAPON_FLAG"  |"PHYSICAL_FORCE_WEAPON_IMPACT_FLAG"  |"STOP_LOCATION_STREET_NAME"  |"STOP_DURATION_MINUTES"  |"PHYSICAL_FORCE_OTHER_FLAG"  |"SUSPECT_SEX"  |"ASK_FOR_CONSENT_FLG"  |"SUMMONS_OFFENSE_DESCRIPTION"  |"STOP_LOCATION_X"  |"SUSPECTS_ACTIONS_CONCEALED_POSSESSION_WEAPON_F...  |"SUSPECTS_ACTIONS_OTHER_FLAG"  |"PHYSICAL_FORCE_CEW_FLAG"  |"STOP_LOCATION_Y"  |"DAY2"  |"FIREARM_FLAG"  |"WEAPON_FOUND_FLAG"  |"MONTH2"  |"SEARCH_BASIS_INCIDENTAL_TO_ARREST_FLAG"  |"SUSPECTS_ACTIONS_DRUG_TRANSACTIONS_FLAG"  |"BACKROUND_CIRCUMSTANCES_VIOLENT_CRIME_FLAG"  |"FRISKED_FLAG"  |"SUSPECT_HAIR_COLOR"  |"SUSPECT_ARREST_OFFENSE"  |"OFFICER_IN_UNIFORM_FLAG"  |"STOP_LOCATION_APARTMENT"  |"JURISDICTION_CODE"  |"SEARCHED_FLAG"  |"SUSPECTED_CRIME_DESCRIPTION"  |"SUSPECT_HEIGHT"  |"SUSPECTS_ACTIONS_DECRIPTION_FLAG"  |"KNIFE_CUTTER_FLAG"  |"SUPERVISING_OFFICER_RANK"  |"STOP_LOCATION_FULL_ADDRESS"  |"OTHER_CONTRABAND_FLAG"  |"SUSPECT_BODY_BUILD_TYPE"  |"PHYSICAL_FORCE_DRAW_POINT_FIREARM_FLAG"  |"DEMEANOR_OF_PERSON_STOPPED"  |"SUSPECT_ARRESTED_FLAG"  |"SUSPECT_RACE_DESCRIPTION"  |"SUSPECT_REPORTED_AGE"  |"SUSPECT_EYE_COLOR"  |"STOP_FRISK_TIME"  |"OBSERVED_DURATION_MINUTES"  |"CONSENT_GIVEN_FLG"  |"STOP_WAS_INITIATED"  |"SEARCH_BASIS_OUTLINE_FLAG"  |"SHIELD_IDENTIFIES_OFFICER_FLAG"  |"ISSUING_OFFICER_RANK"  |"OFFICER_EXPLAINED_STOP_FLAG"  |"STOP_LOCATION_PRECINCT"  |"SUSPECT_OTHER_DESCRIPTION"    |"SUSPECTS_ACTIONS_IDENTIFY_CRIME_PATTERN_FLAG"  |"SUSPECTS_ACTIONS_LOOKOUT_FLAG"  |"STOP_LOCATION_PATROL_BORO_NAME"  |"STOP_LOCATION_BORO_NAME"  |"YEAR2"  |"STOP_FRISK_DATE"  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |Physical Force     |40              |2020059962213          |BRONX             |2020-06-19         |Physical Force       |28     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |48              |2020067962095          |BRONX             |2020-06-19         |Physical Force       |NULL   |FEMALE            |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |46              |2020065962182          |BRONX             |2020-06-19         |Physical Force       |49     |MALE              |HISPANIC        |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |46              |2020065962181          |BRONX             |2020-06-19         |Physical Force       |20     |MALE              |HISPANIC        |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |122             |2020141962045          |STATEN ISLAND     |2020-06-19         |Physical Force       |18     |MALE              |WHITE           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |61              |2020080962067          |BROOKLYN          |2020-06-19         |Physical Force       |28     |MALE              |HISPANIC        |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |113             |2020132962110          |QUEENS            |2020-06-19         |Physical Force       |19     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Electrical Weapon  |46              |2020065962180          |BRONX             |2020-06-19         |No Force             |25     |MALE              |HISPANIC        |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |46              |2020065962179          |BRONX             |2020-06-19         |No Force             |19     |MALE              |BLACK           |NULL                                 |NULL                             |160               |D                            |NULL                 |NULL                                 |SEAVER WAY                   |7                        |NULL                         |MALE           |N                      |NULL                           |1027679            |NULL                                                |NULL                           |NULL                       |214505             |Friday  |NULL            |N                    |June      |Y                                         |NULL                                       |NULL                                          |N               |BRO                   |ROBBERY                   |Y                          |NULL                       |P                    |Y                |ROBBERY                        |5.11              |Y                                   |NULL                 |SGT                         |SEAVER WAY && ROOSEVELT AVE   |N                        |THN                        |NULL                                      |CALM                          |Y                        |WHITE HISPANIC              |40                      |BRO                  |17:24:00           |1                            |N                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |110                       |GREY SHIRT KHAKI PANTS DARK B  |NULL                                            |NULL                             |QUEENS                            |QUEENS                     |2020     |2020-06-19         |
# |Physical Force     |75              |2020094962156          |BROOKLYN          |2020-06-07         |Physical Force       |29     |MALE              |BLACK           |NULL                                 |NULL                             |110               |D                            |NULL                 |NULL                                 |1 AVE                        |33                       |NULL                         |FEMALE         |Y                      |NULL                           |999396             |NULL                                                |NULL                           |NULL                       |224456             |Sunday  |NULL            |N                    |June      |NULL                                      |NULL                                       |NULL                                          |N               |RED                   |NULL                      |Y                          |NULL                       |P                    |Y                |PETIT LARCENY                  |5.3               |Y                                   |NULL                 |SGT                         |1841 1 AVE                    |N                        |THN                        |NULL                                      |NOT ABLE TO SIT STILL         |N                        |WHITE                       |NULL                    |BRO                  |11:50:00           |1                            |Y                    |Based on Radio Run    |NULL                         |NULL                              |POM                     |Y                              |19                        |ORANGE SHIRT                   |NULL                                            |NULL                             |MANHATTAN                         |MANHATTAN                  |2020     |2020-06-07         |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
use_of_force_and_sqf_on_date.count()
# Out:
# 1206145

# %% [markdown]
# ## Exporting Data to Gold Medallion

# %%
table_name = "SAFEGUARDING_NYC_SCHEMA_GOLD.use_of_force_combined"
use_of_force_combined.write.saveAsTable(table_name, mode="overwrite")
